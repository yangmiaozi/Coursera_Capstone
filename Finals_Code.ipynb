# %%
#!conda install -c conda-forge folium=0.5.0 --yes # comment/uncomment if not yet installed.
#!conda install -c conda-forge geopy --yes        # comment/uncomment if not yet installed

import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis

# Numpy and Pandas libraries were already imported at the beginning of this notebook.
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
import folium # map rendering library

import requests # library to handle requests
import lxml.html as lh
import bs4 as bs
import urllib.request

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
from IPython.display import HTML
import base64

# Extra Helper scripts to generate download links for saved dataframes in csv format.
def create_download_link( df, title = "Download CSV file", filename = "data.csv"):  
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

# %%
import zipfile
import os
# !wget -q -O 'median-rent-by-town-and-flat-type.zip' "https://data.gov.sg/dataset/b35046dc-7428-4cff-968d-ef4c3e9e6c99/download"
zf = zipfile.ZipFile('./median-rent-by-town-and-flat-type.zip')
sgp_median_rent_by_town_data = pd.read_csv(zf.open("median-rent-by-town-and-flat-type.csv"))
sgp_median_rent_by_town_data.rename(columns = {'town':'Town'}, inplace = True)
sgp_median_rent_by_town_data.head()
# Out:
#    quarter        Town flat_type median_rent
# 0  2005-Q2  ANG MO KIO      1-RM          na
# 1  2005-Q2  ANG MO KIO      2-RM          na
# 2  2005-Q2  ANG MO KIO      3-RM         800
# 3  2005-Q2  ANG MO KIO      4-RM         950
# 4  2005-Q2  ANG MO KIO      5-RM           -

# %%
# Drop rows with rental price == 'na'.
sgp_median_rent_by_town_data_filter=sgp_median_rent_by_town_data[~sgp_median_rent_by_town_data['median_rent'].isin(['-','na'])]

# Take the most recent report which is "2018-Q2"
sgp_median_rent_by_town_data_filter=sgp_median_rent_by_town_data_filter[sgp_median_rent_by_town_data_filter['quarter'] == "2018-Q2"]

# Now that all rows reports are "2018-Q2", we dont need this column anymore.
sgp_median_rent_by_town_data_filter=sgp_median_rent_by_town_data_filter.drop(['quarter'], axis=1)

# Ensure that median_rent column is float64.
sgp_median_rent_by_town_data_filter['median_rent']=sgp_median_rent_by_town_data_filter['median_rent'].astype(np.float64)

# %%
singapore_average_rental_prices_by_town = sgp_median_rent_by_town_data_filter.groupby(['Town'])['median_rent'].mean().reset_index()
singapore_average_rental_prices_by_town
# Out:
#                Town  median_rent
# 0        ANG MO KIO  2033.333333
# 1             BEDOK  2087.500000
# 2            BISHAN  2233.333333
# 3       BUKIT BATOK  1962.500000
# 4       BUKIT MERAH  2162.500000
# 5     BUKIT PANJANG  1737.500000
# 6           CENTRAL  2450.000000
# 7     CHOA CHU KANG  1933.333333
# 8          CLEMENTI  2263.333333
# 9           GEYLANG  2166.666667
# 10          HOUGANG  1962.500000
# 11      JURONG EAST  2150.000000
# 12      JURONG WEST  1975.000000
# 13  KALLANG/WHAMPOA  2300.000000
# 14    MARINE PARADE  1950.000000
# 15        PASIR RIS  2066.666667
# 16          PUNGGOL  1825.000000
# 17       QUEENSTOWN  2162.500000
# 18        SEMBAWANG  1883.333333
# 19         SENGKANG  1900.000000
# 20        SERANGOON  2187.500000
# 21         TAMPINES  2075.000000
# 22        TOA PAYOH  2210.000000
# 23        WOODLANDS  1762.500000
# 24           YISHUN  1900.000000

# %%
google_key = 'AIzaSyCEZzVH-JYxbZSoiavmI7RNZ_VAc6hKKl8'
singapore_average_rental_prices_by_town['Latitude'] = 0.0
singapore_average_rental_prices_by_town['Longitude'] = 0.0
try:
    for idx,town in singapore_average_rental_prices_by_town['Town'].iteritems():
        address = town + " MRT station, Singapore" ;
        url = 'https://maps.googleapis.com/maps/api/geocode/json?address={}&key={}'.format(address,google_key)
        lat = requests.get(url).json()["results"][0]["geometry"]["location"]['lat']
        lng = requests.get(url).json()["results"][0]["geometry"]["location"]['lng']
        singapore_average_rental_prices_by_town.loc[idx,'Latitude'] = lat
        singapore_average_rental_prices_by_town.loc[idx,'Longitude'] = lng
except:
    geo = Nominatim(user_agent='Mypythonapi')
    for idx,town in singapore_average_rental_prices_by_town['Town'].iteritems():
        coord = geo.geocode(town + ' ' + "Singapore", timeout = 10)
        if coord:
            singapore_average_rental_prices_by_town.loc[idx,'Latitude'] = coord.latitude
            singapore_average_rental_prices_by_town.loc[idx,'Longitude'] = coord.longitude
        else:
            singapore_average_rental_prices_by_town.loc[idx,'Latitude'] = NULL
            singapore_average_rental_prices_by_town.loc[idx,'Longitude'] = NULL

# %%
singapore_average_rental_prices_by_town.set_index("Town")
# Out:
#                  median_rent  Latitude   Longitude
# Town
# ANG MO KIO       2033.333333  1.369842  103.846609
# BEDOK            2087.500000  1.323976  103.930216
# BISHAN           2233.333333  1.351455  103.848263
# BUKIT BATOK      1962.500000  1.349057  103.749591
# BUKIT MERAH      2162.500000  1.280628  103.830591
# BUKIT PANJANG    1737.500000  1.377921  103.771866
# CENTRAL          2450.000000  1.290475  103.852036
# CHOA CHU KANG    1933.333333  1.389260  103.743728
# CLEMENTI         2263.333333  1.314026  103.762410
# GEYLANG          2166.666667  1.318186  103.887056
# HOUGANG          1962.500000  1.373360  103.886091
# JURONG EAST      2150.000000  1.333115  103.742297
# JURONG WEST      1975.000000  1.339636  103.707339
# KALLANG/WHAMPOA  2300.000000  1.319116  103.866291
# MARINE PARADE    1950.000000  1.302689  103.907395
# PASIR RIS        2066.666667  1.375989  103.954360
# PUNGGOL          1825.000000  1.405255  103.902354
# QUEENSTOWN       2162.500000  1.294623  103.806045
# SEMBAWANG        1883.333333  1.448065  103.820760
# SENGKANG         1900.000000  1.390949  103.895175
# SERANGOON        2187.500000  1.349807  103.873771
# TAMPINES         2075.000000  1.354653  103.943571
# TOA PAYOH        2210.000000  1.335391  103.849741
# WOODLANDS        1762.500000  1.436897  103.786216
# YISHUN           1900.000000  1.428136  103.833694

# %%
geo = Nominatim(user_agent='My-IBMNotebook')
address = 'Singapore'
location = geo.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Singapore {}, {}.'.format(latitude, longitude))

# create map of Singapore using latitude and longitude values
map_singapore = folium.Map(location=[latitude, longitude],tiles="OpenStreetMap", zoom_start=10)

# add markers to map
for lat, lng, town in zip(
    singapore_average_rental_prices_by_town['Latitude'],
    singapore_average_rental_prices_by_town['Longitude'],
    singapore_average_rental_prices_by_town['Town']):
    label = town
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#87cefa',
        fill_opacity=0.5,
        parse_html=False).add_to(map_singapore)
map_singapore
# Out:
# The geograpical coordinate of Singapore 1.2904753, 103.8520359.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
fileName = "singapore_average_rpbt.csv"
linkName = "Singapore Average Rental Prices"
create_download_link(singapore_average_rental_prices_by_town,linkName,fileName)
# Out:
# <a download="singapore_average_rpbt.csv" href="data:text/csv;base64,..." target="_blank">Singapore Average Rental Prices</a>

# %%
import time
FOURSQUARE_EXPLORE_URL = 'https://api.foursquare.com/v2/venues/explore?'
FOURSQUARE_SEARCH_URL = 'https://api.foursquare.com/v2/venues/search?'
CLIENT_ID = "WR4I4B4PDJDW2GZIJ5EKECO3JYEUERO0ITAIFLU40YTQO2UP"
CLIENT_SECRET = "2G1SHPBXXPCAJ11Z0LCSIQ5YKQ2TDWSDY3JY4K2E3Y4OUVIX"
VERSION = "20180604"

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    global CLIENT_ID
    global CLIENT_SECRET
    global FOURSQUARE_EXPLORE_URL
    global FOURSQUARE_SEARCH_URL
    global VERSION
    global LIMIT
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print('getNearbyVenues',names)
        cyclefsk2()
        url = '{}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            FOURSQUARE_EXPLORE_URL,CLIENT_ID,CLIENT_SECRET,VERSION,
            lat,lng,radius,LIMIT)
            
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name,lat,lng, 
            v['venue']['id'],v['venue']['name'], 
            v['venue']['location']['lat'],v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
        time.sleep(2)

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Town','Town Latitude','Town Longitude','Venue','Venue Latitude','Venue Longitude','Venue Category']
    
    return(nearby_venues)

# %%
FOURSQUARE_SEARCH_URL = 'https://api.foursquare.com/v2/venues/search?'
venue_id_rcols = ['VenueID']
venue_id_recover = pd.DataFrame(columns=venue_id_rcols)
LIMIT = 30
def getVenuesByCategory(names, latitudes, longitudes, categoryID, radius=500):
    global CLIENT_ID
    global CLIENT_SECRET
    global FOURSQUARE_EXPLORE_URL
    global FOURSQUARE_SEARCH_URL
    global VERSION
    global LIMIT
    venue_columns = ['Town','Town Latitude','Town Longitude','VenueID','VenueName','score','category','catID','latitude','longitude']
    venue_DF = pd.DataFrame(columns=venue_columns)
    print("[#Start getVenuesByCategory]")
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name,",",end='')
        url = '{}client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            FOURSQUARE_SEARCH_URL,CLIENT_ID,CLIENT_SECRET,VERSION,lat,lng,radius,LIMIT,categoryID)
        results = requests.get(url).json()
        
        for jsonSub in results['response']['venues']:
            ven_id = 0
            try:
                ven_id   = jsonSub['id']
                ven_cat  = jsonSub['categories'][0]['pluralName']
                ven_CID  = jsonSub['categories'][0]['id']
                ven_name = jsonSub['name']
                ven_lat  = jsonSub['location']['lat']
                ven_lng  = jsonSub['location']['lng']
                venue_DF = venue_DF.append({
                    'Town'      : name,
                    'Town Latitude' : lat,
                    'Town Longitude': lng,
                    'VenueID'   : ven_id,
                    'VenueName' : ven_name,
                    'score'     : 'nan',
                    'category'  : ven_cat,
                    'catID'     : ven_CID,
                    'latitude'  : ven_lat,
                    'longitude' : ven_lng}, ignore_index=True)
            except:
                continue
    print("\n[#Done getVenuesByCategory]")
    return(venue_DF)

# %%
FOURSQUARE_SEARCH_URL = 'https://api.foursquare.com/v2/venues/search?'

venue_id_rcols = ['VenueID','Score']
venue_id_recover = pd.DataFrame(columns=venue_id_rcols)

def getVenuesIDScore(venueID):
    global CLIENT_ID
    global CLIENT_SECRET
    global FOURSQUARE_EXPLORE_URL
    global FOURSQUARE_SEARCH_URL
    global VERSION
    global LIMIT
    global venue_id_recover
    print("[#getVenuesIDScore]")
    venID_URL = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venueID,CLIENT_ID,CLIENT_SECRET,VERSION)
    print(venID_URL)
    venID_score = 0.00
    try:
        venID_result = requests.get(venID_URL).json()
        venID_score  = venID_result['response']['venue']['rating']
    except: 
        venue_id_recover = venue_id_recover.append({'VenueID' : venueID, 'Score' : 0.0})
        return ["error",0.0]
    return ["success",venID_score]

# %%
singapore_average_rental_prices_by_town.dtypes
# Out:
# Town            object
# median_rent    float64
# Latitude       float64
# Longitude      float64
# dtype: object

# %%
venue_columns = ['Town','Town Latitude','Town Longitude','VenueID','VenueName','score','category','catID','latitude','longitude']
singapore_town_venues = pd.DataFrame(columns=venue_columns)

# %%
if (0):
    categoryID = "4d4b7105d754a06377d81259"
    town_names = ['ANG MO KIO']
    lat_list   = [1.3699718]
    lng_list   = [103.8495876]
    tmp = getVenuesByCategory(names=town_names,latitudes=lat_list,longitudes=lng_list,categoryID=categoryID)
    singapore_town_venues = pd.concat([singapore_town_venues,tmp], ignore_index=True)

# %%
categoryID = "4d4b7105d754a06374d81259"
town_names = singapore_average_rental_prices_by_town['Town']
lat_list   = singapore_average_rental_prices_by_town['Latitude']
lng_list   = singapore_average_rental_prices_by_town['Longitude']
singapore_food_venues = getVenuesByCategory(names=town_names,latitudes=lat_list,longitudes=lng_list,categoryID=categoryID)
# Out:
# [#Start getVenuesByCategory]
# ANG MO KIO ,BEDOK ,BISHAN ,BUKIT BATOK ,BUKIT MERAH ,BUKIT PANJANG ,CENTRAL ,CHOA CHU KANG ,CLEMENTI ,GEYLANG ,HOUGANG ,JURONG EAST ,JURONG WEST ,KALLANG/WHAMPOA ,MARINE PARADE ,PASIR RIS ,PUNGGOL ,QUEENSTOWN ,SEMBAWANG ,SENGKANG ,SERANGOON ,TAMPINES ,TOA PAYOH ,WOODLANDS ,YISHUN ,
# [#Done getVenuesByCategory]

# %%
fileName = "singapore_food_venues.Category.csv"
linkName = "IBM Storage Link:singapore_food_venues.Category.csv"
create_download_link(singapore_food_venues,linkName,fileName)
# Out:
# <a download="singapore_food_venues.Category.csv" href="data:text/csv;base64,..." target="_blank">IBM Storage Link:singapore_food_venues.Category.csv</a>

# %%
score_is_NAN = len(singapore_food_venues[singapore_food_venues['score'].isnull()].index.tolist())
print("Current score=NaN count=",score_is_NAN)
for idx in singapore_food_venues[singapore_food_venues['score'].isnull()].index.tolist():
    venueID = singapore_food_venues.loc[idx,'VenueID']
    status,score = getVenuesIDScore(venueID)
    if status == "success":
        singapore_food_venues.loc[idx,'score'] = score
score_is_NAN = len(singapore_food_venues[singapore_food_venues['score'].isnull()].index.tolist())
print("PostRun score=NaN count=",score_is_NAN)
print('Done',end='')
# Out:
# Current score=NaN count= 0
# PostRun score=NaN count= 0
# Done

# %%
if (0):
    singapore_town_venues = pd.concat([singapore_food_venues,singapore_outdoor_venues_by_town,singapore_Nightlife_by_town], ignore_index=True)
#else
singapore_town_venues = singapore_food_venues
singapore_town_venues.shape
# Out:
# (750, 10)

# %%
singapore_town_venues = singapore_town_venues[venue_columns]
singapore_town_venues = singapore_town_venues.dropna(axis='columns')

# %%
singapore_town_venues.shape
# Out:
# (750, 10)

# %%
singapore_town_venues.head()
# Out:
#          Town  Town Latitude  Town Longitude                   VenueID  \
# 0  ANG MO KIO       1.369842      103.846609  4d3c0d2d457cb60c8450eca4
# 1  ANG MO KIO       1.369842      103.846609  4b83bd62f964a520c80e31e3
# 2  ANG MO KIO       1.369842      103.846609  4c13737877cea59381cbce60
# 3  ANG MO KIO       1.369842      103.846609  4b6a90a5f964a520c7d82be3
# 4  ANG MO KIO       1.369842      103.846609  4b06a9c8f964a52059ee22e3
#
#            VenueName score               category                     catID  \
# 0                S11   nan            Food Courts  4bf58dd8d48988d120951735
# 1  McDonald's/McCafe   nan  Fast Food Restaurants  4bf58dd8d48988d16e941735
# 2                KFC   nan  Fast Food Restaurants  4bf58dd8d48988d16e941735
# 3           KOI Café   nan       Bubble Tea Shops  52e81612bcbc57f1066b7a0c
# 4       Pepper Lunch   nan   Japanese Restaurants  4bf58dd8d48988d111941735
#
#    latitude   longitude
# 0  1.369234  103.847280
# 1  1.369385  103.847365
# 2  1.370801  103.845664
# 3  1.370569  103.847237
# 4  1.369107  103.847791

# %%
fileName = "recommended.singapore_town_venues.csv"
linkName = "IBM Storage Link:recommended_singapore_town_venues.csv"
create_download_link(singapore_food_venues,linkName,fileName)
# Out:
# <a download="recommended.singapore_town_venues.csv" href="data:text/csv;base64,..." target="_blank">IBM Storage Link:recommended_singapore_town_venues.csv</a>

# %%
singapore_town_venues.groupby('Town').count()
# Out:
#                  Town Latitude  Town Longitude  VenueID  VenueName  score  \
# Town
# ANG MO KIO                  30              30       30         30     30
# BEDOK                       30              30       30         30     30
# BISHAN                      30              30       30         30     30
# BUKIT BATOK                 30              30       30         30     30
# BUKIT MERAH                 30              30       30         30     30
# BUKIT PANJANG               30              30       30         30     30
# CENTRAL                     30              30       30         30     30
# CHOA CHU KANG               30              30       30         30     30
# CLEMENTI                    30              30       30         30     30
# GEYLANG                     30              30       30         30     30
# HOUGANG                     30              30       30         30     30
# JURONG EAST                 30              30       30         30     30
# JURONG WEST                 30              30       30         30     30
# KALLANG/WHAMPOA             30              30       30         30     30
# MARINE PARADE               30              30       30         30     30
# PASIR RIS                   30              30       30         30     30
# PUNGGOL                     30              30       30         30     30
# QUEENSTOWN                  30              30       30         30     30
# SEMBAWANG                   30              30       30         30     30
# SENGKANG                    30              30       30         30     30
# SERANGOON                   30              30       30         30     30
# TAMPINES                    30              30       30         30     30
# TOA PAYOH                   30              30       30         30     30
# WOODLANDS                   30              30       30         30     30
# YISHUN                      30              30       30         30     30
#
#                  category  catID  latitude  longitude
# Town
# ANG MO KIO             30     30        30         30
# BEDOK                  30     30        30         30
# BISHAN                 30     30        30         30
# BUKIT BATOK            30     30        30         30
# BUKIT MERAH            30     30        30         30
# BUKIT PANJANG          30     30        30         30
# CENTRAL                30     30        30         30
# CHOA CHU KANG          30     30        30         30
# CLEMENTI               30     30        30         30
# GEYLANG                30     30        30         30
# HOUGANG                30     30        30         30
# JURONG EAST            30     30        30         30
# JURONG WEST            30     30        30         30
# KALLANG/WHAMPOA        30     30        30         30
# MARINE PARADE          30     30        30         30
# PASIR RIS              30     30        30         30
# PUNGGOL                30     30        30         30
# QUEENSTOWN             30     30        30         30
# SEMBAWANG              30     30        30         30
# SENGKANG               30     30        30         30
# SERANGOON              30     30        30         30
# TAMPINES               30     30        30         30
# TOA PAYOH              30     30        30         30
# WOODLANDS              30     30        30         30
# YISHUN                 30     30        30         30

# %%
singapore_town_venues.dtypes
# Out:
# Town               object
# Town Latitude     float64
# Town Longitude    float64
# VenueID            object
# VenueName          object
# score              object
# category           object
# catID              object
# latitude          float64
# longitude         float64
# dtype: object

# %%
print('There are {} uniques categories.'.format(len(singapore_town_venues['category'].unique())))
# Out:
# There are 73 uniques categories.

# %%
singapore_town_venues.groupby('category')['VenueName'].count().sort_values(ascending=False)[:20]
# Out:
# category
# Food Courts              103
# Chinese Restaurants       72
# Coffee Shops              67
# Fast Food Restaurants     59
# Cafés                     52
# Noodle Houses             24
# Japanese Restaurants      23
# Asian Restaurants         23
# Bakeries                  19
# Bubble Tea Shops          17
# Dessert Shops             16
# Sushi Restaurants         14
# Indian Restaurants        13
# Seafood Restaurants       12
# Restaurants               11
# Snack Places              11
# Steakhouses               11
# American Restaurants      10
# BBQ Joints                 9
# Ice Cream Shops            9
# Name: VenueName, dtype: int64

# %%
sg_onehot = pd.get_dummies(singapore_town_venues[['category']], prefix="", prefix_sep="")

# add Town column back to dataframe
sg_onehot['Town'] = singapore_town_venues['Town'] 

# move neighborhood column to the first column
fixed_columns = [sg_onehot.columns[-1]] + list(sg_onehot.columns[:-1])
sg_onehot = sg_onehot[fixed_columns]

# Check returned one hot encoding data:
print('One hot encoding returned "{}" rows.'.format(sg_onehot.shape[0]))

# Regroup rows by town and mean of frequency occurrence per category.
sg_grouped = sg_onehot.groupby('Town').mean().reset_index()

print('One hot encoding re-group returned "{}" rows.'.format(sg_grouped.shape[0]))
sg_grouped.head()
# Out:
# One hot encoding returned "750" rows.
# One hot encoding re-group returned "25" rows.
#           Town  American Restaurants  Asian Restaurants  BBQ Joints  Bakeries  \
# 0   ANG MO KIO              0.000000           0.000000         0.0  0.033333
# 1        BEDOK              0.000000           0.000000         0.0  0.033333
# 2       BISHAN              0.000000           0.000000         0.0  0.033333
# 3  BUKIT BATOK              0.000000           0.066667         0.0  0.033333
# 4  BUKIT MERAH              0.033333           0.066667         0.0  0.100000
#
#    Bistros  Breakfast Spots  Bubble Tea Shops  Buffets  Burger Joints  \
# 0      0.0         0.000000          0.100000      0.0       0.000000
# 1      0.0         0.033333          0.033333      0.0       0.033333
# 2      0.0         0.000000          0.066667      0.0       0.000000
# 3      0.0         0.000000          0.066667      0.0       0.000000
# 4      0.0         0.000000          0.000000      0.0       0.000000
#
#    Burrito Places  Cafeterias     Cafés  Cantonese Restaurants  \
# 0        0.000000         0.0  0.033333                    0.0
# 1        0.000000         0.0  0.033333                    0.0
# 2        0.033333         0.0  0.066667                    0.0
# 3        0.000000         0.0  0.000000                    0.0
# 4        0.000000         0.0  0.200000                    0.0
#
#    Chinese Breakfast Places  Chinese Restaurants  Coffee Shops  \
# 0                       0.0             0.000000      0.033333
# 1                       0.0             0.033333      0.066667
# 2                       0.0             0.133333      0.133333
# 3                       0.0             0.100000      0.100000
# 4                       0.0             0.166667      0.066667
#
#    Comfort Food Restaurants  Cupcake Shops  Dessert Shops  \
# 0                       0.0       0.000000       0.033333
# 1                       0.0       0.000000       0.000000
# 2                       0.0       0.000000       0.000000
# 3                       0.0       0.000000       0.000000
# 4                       0.0       0.033333       0.000000
#
#    Dim Sum Restaurants    Diners  Dumpling Restaurants  Fast Food Restaurants  \
# 0                  0.0  0.033333              0.000000               0.133333
# 1                  0.0  0.000000              0.033333               0.066667
# 2                  0.0  0.000000              0.033333               0.066667
# 3                  0.0  0.000000              0.000000               0.066667
# 4                  0.0  0.000000              0.000000               0.000000
#
#    Food Courts  Food Stands  Food Trucks  French Restaurants  \
# 0     0.200000          0.0          0.0                 0.0
# 1     0.133333          0.0          0.0                 0.0
# 2     0.100000          0.0          0.0                 0.0
# 3     0.233333          0.0          0.0                 0.0
# 4     0.100000          0.0          0.0                 0.0
#
#    Fried Chicken Joints  Frozen Yogurt Shops  German Restaurants  \
# 0              0.000000                  0.0                 0.0
# 1              0.033333                  0.0                 0.0
# 2              0.033333                  0.0                 0.0
# 3              0.000000                  0.0                 0.0
# 4              0.000000                  0.0                 0.0
#
#    Greek Restaurants  Grocery Stores  Hainan Restaurants  Halal Restaurants  \
# 0                0.0        0.000000            0.000000           0.033333
# 1                0.0        0.000000            0.000000           0.000000
# 2                0.0        0.000000            0.000000           0.000000
# 3                0.0        0.033333            0.000000           0.000000
# 4                0.0        0.000000            0.033333           0.000000
#
#    Hong Kong Restaurants  Hotpot Restaurants  Ice Cream Shops  \
# 0                    0.0            0.000000         0.000000
# 1                    0.0            0.033333         0.033333
# 2                    0.0            0.033333         0.000000
# 3                    0.0            0.000000         0.066667
# 4                    0.0            0.000000         0.033333
#
#    Indian Restaurants  Indonesian Restaurants  Italian Restaurants  \
# 0            0.000000                     0.0             0.000000
# 1            0.033333                     0.0             0.000000
# 2            0.033333                     0.0             0.000000
# 3            0.033333                     0.0             0.033333
# 4            0.000000                     0.0             0.033333
#
#    Japanese Curry Restaurants  Japanese Restaurants  Juice Bars  \
# 0                         0.0              0.033333         0.0
# 1                         0.0              0.100000         0.0
# 2                         0.0              0.100000         0.0
# 3                         0.0              0.000000         0.0
# 4                         0.0              0.033333         0.0
#
#    Korean Restaurants  Lounges  Malay Restaurants  Markets  \
# 0            0.000000      0.0           0.033333      0.0
# 1            0.000000      0.0           0.000000      0.0
# 2            0.000000      0.0           0.000000      0.0
# 3            0.000000      0.0           0.000000      0.0
# 4            0.033333      0.0           0.000000      0.0
#
#    Mexican Restaurants  Miscellaneous Shops  Modern European Restaurants  \
# 0                  0.0             0.033333                     0.033333
# 1                  0.0             0.000000                     0.000000
# 2                  0.0             0.000000                     0.000000
# 3                  0.0             0.000000                     0.000000
# 4                  0.0             0.000000                     0.000000
#
#    Noodle Houses  Pastry Shops  Pharmacies  Pizza Places  Plazas  \
# 0       0.000000      0.033333    0.033333      0.000000     0.0
# 1       0.066667      0.000000    0.000000      0.000000     0.0
# 2       0.000000      0.000000    0.000000      0.000000     0.0
# 3       0.000000      0.000000    0.000000      0.033333     0.0
# 4       0.000000      0.000000    0.000000      0.000000     0.0
#
#    Portuguese Restaurants  Ramen Restaurants  Restaurants  Salad Places  \
# 0                     0.0           0.033333     0.033333           0.0
# 1                     0.0           0.000000     0.033333           0.0
# 2                     0.0           0.000000     0.000000           0.0
# 3                     0.0           0.000000     0.033333           0.0
# 4                     0.0           0.000000     0.000000           0.0
#
#    Sandwich Places  Seafood Restaurants  Shaanxi Restaurants  \
# 0         0.033333             0.000000             0.000000
# 1         0.000000             0.000000             0.000000
# 2         0.000000             0.033333             0.033333
# 3         0.033333             0.000000             0.000000
# 4         0.000000             0.033333             0.000000
#
#    Shabu-Shabu Restaurants  Snack Places  Soup Places  Sports Bars  \
# 0                      0.0      0.033333     0.000000          0.0
# 1                      0.0      0.033333     0.000000          0.0
# 2                      0.0      0.000000     0.000000          0.0
# 3                      0.0      0.033333     0.000000          0.0
# 4                      0.0      0.000000     0.033333          0.0
#
#    Steakhouses  Sushi Restaurants  Taiwanese Restaurants  Thai Restaurants  \
# 0          0.0           0.033333                    0.0          0.000000
# 1          0.0           0.033333                    0.0          0.033333
# 2          0.0           0.033333                    0.0          0.033333
# 3          0.0           0.000000                    0.0          0.000000
# 4          0.0           0.000000                    0.0          0.000000
#
#    Vegetarian / Vegan Restaurants  Vietnamese Restaurants  Wings Joints
# 0                        0.000000                     0.0      0.000000
# 1                        0.033333                     0.0      0.033333
# 2                        0.000000                     0.0      0.000000
# 3                        0.033333                     0.0      0.000000
# 4                        0.000000                     0.0      0.000000

# %%
num_top_venues = 10
for town in sg_grouped['Town']:
    print("# Town=< "+town+" >")
    temp = sg_grouped[sg_grouped['Town'] == town].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# # Town=< ANG MO KIO >
#                          venue  freq
# 0                  Food Courts  0.20
# 1        Fast Food Restaurants  0.13
# 2             Bubble Tea Shops  0.10
# 3                       Diners  0.03
# 4  Modern European Restaurants  0.03
# 5            Ramen Restaurants  0.03
# 6                  Restaurants  0.03
# 7                   Pharmacies  0.03
# 8         Japanese Restaurants  0.03
# 9              Sandwich Places  0.03
#
#
# # Town=< BEDOK >
#                             venue  freq
# 0                     Food Courts  0.13
# 1            Japanese Restaurants  0.10
# 2                    Coffee Shops  0.07
# 3                   Noodle Houses  0.07
# 4           Fast Food Restaurants  0.07
# 5                 Ice Cream Shops  0.03
# 6  Vegetarian / Vegan Restaurants  0.03
# 7                Thai Restaurants  0.03
# 8               Sushi Restaurants  0.03
# 9                    Snack Places  0.03
#
#
# # Town=< BISHAN >
#                    venue  freq
# 0    Chinese Restaurants  0.13
# 1           Coffee Shops  0.13
# 2   Japanese Restaurants  0.10
# 3            Food Courts  0.10
# 4                  Cafés  0.07
# 5  Fast Food Restaurants  0.07
# 6       Bubble Tea Shops  0.07
# 7    Seafood Restaurants  0.03
# 8    Shaanxi Restaurants  0.03
# 9     Hotpot Restaurants  0.03
#
#
# # Town=< BUKIT BATOK >
#                    venue  freq
# 0            Food Courts  0.23
# 1    Chinese Restaurants  0.10
# 2           Coffee Shops  0.10
# 3        Ice Cream Shops  0.07
# 4      Asian Restaurants  0.07
# 5       Bubble Tea Shops  0.07
# 6  Fast Food Restaurants  0.07
# 7    Italian Restaurants  0.03
# 8     Indian Restaurants  0.03
# 9         Grocery Stores  0.03
#
#
# # Town=< BUKIT MERAH >
#                   venue  freq
# 0                 Cafés  0.20
# 1   Chinese Restaurants  0.17
# 2              Bakeries  0.10
# 3           Food Courts  0.10
# 4     Asian Restaurants  0.07
# 5          Coffee Shops  0.07
# 6  American Restaurants  0.03
# 7           Soup Places  0.03
# 8   Seafood Restaurants  0.03
# 9    Korean Restaurants  0.03
#
#
# # Town=< BUKIT PANJANG >
#                             venue  freq
# 0                   Noodle Houses  0.13
# 1                     Food Courts  0.13
# 2             Chinese Restaurants  0.10
# 3                    Coffee Shops  0.10
# 4            American Restaurants  0.07
# 5             Seafood Restaurants  0.07
# 6                     Food Trucks  0.07
# 7  Vegetarian / Vegan Restaurants  0.03
# 8                    Salad Places  0.03
# 9                          Plazas  0.03
#
#
# # Town=< CENTRAL >
#                    venue  freq
# 0            Food Courts  0.13
# 1    Seafood Restaurants  0.10
# 2                  Cafés  0.10
# 3           Coffee Shops  0.10
# 4       Bubble Tea Shops  0.07
# 5  Fast Food Restaurants  0.07
# 6   Dumpling Restaurants  0.03
# 7    Chinese Restaurants  0.03
# 8    Italian Restaurants  0.03
# 9           Pizza Places  0.03
#
#
# # Town=< CHOA CHU KANG >
#                    venue  freq
# 0  Fast Food Restaurants  0.13
# 1    Chinese Restaurants  0.10
# 2            Food Courts  0.10
# 3      Asian Restaurants  0.10
# 4          Dessert Shops  0.10
# 5            Restaurants  0.07
# 6      Sushi Restaurants  0.07
# 7           Coffee Shops  0.07
# 8                  Cafés  0.07
# 9                 Diners  0.03
#
#
# # Town=< CLEMENTI >
#                    venue  freq
# 0            Food Courts  0.27
# 1    Chinese Restaurants  0.07
# 2  Fast Food Restaurants  0.07
# 3          Dessert Shops  0.07
# 4           Coffee Shops  0.07
# 5            Soup Places  0.07
# 6   American Restaurants  0.03
# 7         Grocery Stores  0.03
# 8    Dim Sum Restaurants  0.03
# 9           Pastry Shops  0.03
#
#
# # Town=< GEYLANG >
#                             venue  freq
# 0             Chinese Restaurants  0.20
# 1           Fast Food Restaurants  0.13
# 2                     Food Courts  0.10
# 3  Vegetarian / Vegan Restaurants  0.10
# 4                   Noodle Houses  0.10
# 5                      BBQ Joints  0.07
# 6               Asian Restaurants  0.07
# 7                   Dessert Shops  0.07
# 8           Cantonese Restaurants  0.03
# 9             Seafood Restaurants  0.03
#
#
# # Town=< HOUGANG >
#                    venue  freq
# 0           Coffee Shops  0.23
# 1          Noodle Houses  0.10
# 2            Food Courts  0.10
# 3            Steakhouses  0.07
# 4  Fast Food Restaurants  0.07
# 5      Asian Restaurants  0.07
# 6        Sandwich Places  0.03
# 7    Chinese Restaurants  0.03
# 8                  Cafés  0.03
# 9        Ice Cream Shops  0.03
#
#
# # Town=< JURONG EAST >
#                    venue  freq
# 0  Fast Food Restaurants  0.13
# 1    Chinese Restaurants  0.13
# 2            Food Courts  0.10
# 3       Thai Restaurants  0.07
# 4           Coffee Shops  0.07
# 5                  Cafés  0.07
# 6   American Restaurants  0.03
# 7           Snack Places  0.03
# 8    Italian Restaurants  0.03
# 9     Hotpot Restaurants  0.03
#
#
# # Town=< JURONG WEST >
#                         venue  freq
# 0                 Food Courts  0.13
# 1       Fast Food Restaurants  0.13
# 2        Japanese Restaurants  0.10
# 3           Asian Restaurants  0.10
# 4         Chinese Restaurants  0.07
# 5          Korean Restaurants  0.07
# 6                       Cafés  0.07
# 7  Japanese Curry Restaurants  0.03
# 8       Hong Kong Restaurants  0.03
# 9               Noodle Houses  0.03
#
#
# # Town=< KALLANG/WHAMPOA >
#                    venue  freq
# 0    Chinese Restaurants  0.23
# 1            Food Courts  0.13
# 2  Fast Food Restaurants  0.07
# 3      Asian Restaurants  0.07
# 4             Cafeterias  0.07
# 5           Coffee Shops  0.07
# 6            Soup Places  0.03
# 7            Restaurants  0.03
# 8             Juice Bars  0.03
# 9    Seafood Restaurants  0.03
#
#
# # Town=< MARINE PARADE >
#                  venue  freq
# 0         Coffee Shops  0.13
# 1             Bakeries  0.07
# 2              Bistros  0.07
# 3        Noodle Houses  0.07
# 4  Seafood Restaurants  0.07
# 5          Food Courts  0.07
# 6                Cafés  0.07
# 7  Chinese Restaurants  0.07
# 8      Ice Cream Shops  0.03
# 9        Dessert Shops  0.03
#
#
# # Town=< PASIR RIS >
#                    venue  freq
# 0                  Cafés  0.13
# 1               Bakeries  0.07
# 2           Snack Places  0.07
# 3            Food Courts  0.07
# 4  Fast Food Restaurants  0.07
# 5    Chinese Restaurants  0.07
# 6           Coffee Shops  0.07
# 7   American Restaurants  0.03
# 8                 Diners  0.03
# 9      Sushi Restaurants  0.03
#
#
# # Town=< PUNGGOL >
#                    venue  freq
# 0    Chinese Restaurants  0.13
# 1            Food Courts  0.13
# 2                  Cafés  0.10
# 3  Fast Food Restaurants  0.07
# 4        Ice Cream Shops  0.03
# 5   Japanese Restaurants  0.03
# 6          Noodle Houses  0.03
# 7           Pizza Places  0.03
# 8    Frozen Yogurt Shops  0.03
# 9            Restaurants  0.03
#
#
# # Town=< QUEENSTOWN >
#                             venue  freq
# 0             Chinese Restaurants  0.23
# 1                     Food Courts  0.17
# 2                           Cafés  0.17
# 3                   Noodle Houses  0.07
# 4              Indian Restaurants  0.07
# 5                   Dessert Shops  0.07
# 6             Italian Restaurants  0.03
# 7  Vegetarian / Vegan Restaurants  0.03
# 8                Thai Restaurants  0.03
# 9                 Breakfast Spots  0.03
#
#
# # Town=< SEMBAWANG >
#                    venue  freq
# 0           Coffee Shops  0.20
# 1      Asian Restaurants  0.10
# 2            Food Courts  0.10
# 3  Fast Food Restaurants  0.07
# 4             BBQ Joints  0.07
# 5            Soup Places  0.03
# 6             Juice Bars  0.03
# 7   Japanese Restaurants  0.03
# 8     Hotpot Restaurants  0.03
# 9      Halal Restaurants  0.03
#
#
# # Town=< SENGKANG >
#                    venue  freq
# 0                  Cafés  0.17
# 1               Bakeries  0.10
# 2  Fast Food Restaurants  0.10
# 3            Food Courts  0.07
# 4           Coffee Shops  0.07
# 5             Cafeterias  0.07
# 6    Chinese Restaurants  0.07
# 7     Korean Restaurants  0.03
# 8    Frozen Yogurt Shops  0.03
# 9      Ramen Restaurants  0.03
#
#
# # Town=< SERANGOON >
#                         venue  freq
# 0       Fast Food Restaurants  0.17
# 1                Coffee Shops  0.10
# 2                       Cafés  0.10
# 3        Japanese Restaurants  0.07
# 4                 Food Courts  0.07
# 5        American Restaurants  0.03
# 6         Chinese Restaurants  0.03
# 7  Japanese Curry Restaurants  0.03
# 8          Indian Restaurants  0.03
# 9               Noodle Houses  0.03
#
#
# # Town=< TAMPINES >
#                      venue  freq
# 0              Food Courts  0.23
# 1             Coffee Shops  0.13
# 2    Fast Food Restaurants  0.10
# 3       Hotpot Restaurants  0.07
# 4     Dumpling Restaurants  0.03
# 5        Asian Restaurants  0.03
# 6       French Restaurants  0.03
# 7   Portuguese Restaurants  0.03
# 8              Restaurants  0.03
# 9  Shabu-Shabu Restaurants  0.03
#
#
# # Town=< TOA PAYOH >
#                       venue  freq
# 0              Coffee Shops  0.23
# 1               Food Courts  0.13
# 2                     Cafés  0.13
# 3       Chinese Restaurants  0.13
# 4     Fast Food Restaurants  0.10
# 5               Steakhouses  0.10
# 6           Sandwich Places  0.03
# 7  Chinese Breakfast Places  0.03
# 8                    Diners  0.03
# 9         Asian Restaurants  0.03
#
#
# # Town=< WOODLANDS >
#                    venue  freq
# 0            Food Courts  0.20
# 1   Japanese Restaurants  0.10
# 2           Snack Places  0.10
# 3                  Cafés  0.07
# 4  Fast Food Restaurants  0.07
# 5           Coffee Shops  0.07
# 6    Chinese Restaurants  0.07
# 7   American Restaurants  0.07
# 8           Pizza Places  0.03
# 9             BBQ Joints  0.03
#
#
# # Town=< YISHUN >
#                    venue  freq
# 0            Food Courts  0.23
# 1    Chinese Restaurants  0.13
# 2  Fast Food Restaurants  0.07
# 3          Noodle Houses  0.07
# 4     Hainan Restaurants  0.07
# 5           Coffee Shops  0.07
# 6   Japanese Restaurants  0.03
# 7                  Cafés  0.03
# 8             Juice Bars  0.03
# 9           Pastry Shops  0.03

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Town']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
town_venues_sorted = pd.DataFrame(columns=columns)
town_venues_sorted['Town'] = sg_grouped['Town']

for ind in np.arange(sg_grouped.shape[0]):
    town_venues_sorted.iloc[ind, 1:] = return_most_common_venues(sg_grouped.iloc[ind, :], num_top_venues)

print(town_venues_sorted.shape)
town_venues_sorted.head()
# Out:
# (25, 11)
#           Town 1st Most Common Venue  2nd Most Common Venue  \
# 0   ANG MO KIO           Food Courts  Fast Food Restaurants
# 1        BEDOK           Food Courts   Japanese Restaurants
# 2       BISHAN          Coffee Shops    Chinese Restaurants
# 3  BUKIT BATOK           Food Courts    Chinese Restaurants
# 4  BUKIT MERAH                 Cafés    Chinese Restaurants
#
#   3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0      Bubble Tea Shops          Pastry Shops            Restaurants
# 1         Noodle Houses          Coffee Shops  Fast Food Restaurants
# 2           Food Courts  Japanese Restaurants  Fast Food Restaurants
# 3          Coffee Shops      Bubble Tea Shops  Fast Food Restaurants
# 4              Bakeries           Food Courts      Asian Restaurants
#
#   6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 0          Coffee Shops   Miscellaneous Shops  Modern European Restaurants
# 1          Wings Joints              Bakeries              Breakfast Spots
# 2                 Cafés      Bubble Tea Shops          Shaanxi Restaurants
# 3       Ice Cream Shops     Asian Restaurants               Grocery Stores
# 4          Coffee Shops       Ice Cream Shops           Korean Restaurants
#
#   9th Most Common Venue          10th Most Common Venue
# 0         Dessert Shops                      Pharmacies
# 1      Bubble Tea Shops                   Burger Joints
# 2        Burrito Places            Fried Chicken Joints
# 3       Sandwich Places  Vegetarian / Vegan Restaurants
# 4         Cupcake Shops              Hainan Restaurants

# %%
kclusters = 5
sg_grouped_clustering = sg_grouped.drop('Town', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=1).fit(sg_grouped_clustering)

print(kmeans.labels_[0:10])
print(len(kmeans.labels_))
# Out:
# [0 1 1 0 4 1 1 2 0 2]
# 25

# %%
town_venues_sorted.head()
# Out:
#           Town 1st Most Common Venue  2nd Most Common Venue  \
# 0   ANG MO KIO           Food Courts  Fast Food Restaurants
# 1        BEDOK           Food Courts   Japanese Restaurants
# 2       BISHAN          Coffee Shops    Chinese Restaurants
# 3  BUKIT BATOK           Food Courts    Chinese Restaurants
# 4  BUKIT MERAH                 Cafés    Chinese Restaurants
#
#   3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0      Bubble Tea Shops          Pastry Shops            Restaurants
# 1         Noodle Houses          Coffee Shops  Fast Food Restaurants
# 2           Food Courts  Japanese Restaurants  Fast Food Restaurants
# 3          Coffee Shops      Bubble Tea Shops  Fast Food Restaurants
# 4              Bakeries           Food Courts      Asian Restaurants
#
#   6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 0          Coffee Shops   Miscellaneous Shops  Modern European Restaurants
# 1          Wings Joints              Bakeries              Breakfast Spots
# 2                 Cafés      Bubble Tea Shops          Shaanxi Restaurants
# 3       Ice Cream Shops     Asian Restaurants               Grocery Stores
# 4          Coffee Shops       Ice Cream Shops           Korean Restaurants
#
#   9th Most Common Venue          10th Most Common Venue
# 0         Dessert Shops                      Pharmacies
# 1      Bubble Tea Shops                   Burger Joints
# 2        Burrito Places            Fried Chicken Joints
# 3       Sandwich Places  Vegetarian / Vegan Restaurants
# 4         Cupcake Shops              Hainan Restaurants

# %%
town_venues_sorted = town_venues_sorted.set_index("Town")
sg_merged = singapore_average_rental_prices_by_town.set_index("Town")
sg_merged['Cluster Labels'] = kmeans.labels_
sg_merged = sg_merged.join(town_venues_sorted)
sg_merged
# Out:
#                  median_rent  Latitude   Longitude  Cluster Labels  \
# Town
# ANG MO KIO       2033.333333  1.369842  103.846609               0
# BEDOK            2087.500000  1.323976  103.930216               1
# BISHAN           2233.333333  1.351455  103.848263               1
# BUKIT BATOK      1962.500000  1.349057  103.749591               0
# BUKIT MERAH      2162.500000  1.280628  103.830591               4
# BUKIT PANJANG    1737.500000  1.377921  103.771866               1
# CENTRAL          2450.000000  1.290475  103.852036               1
# CHOA CHU KANG    1933.333333  1.389260  103.743728               2
# CLEMENTI         2263.333333  1.314026  103.762410               0
# GEYLANG          2166.666667  1.318186  103.887056               2
# HOUGANG          1962.500000  1.373360  103.886091               3
# JURONG EAST      2150.000000  1.333115  103.742297               1
# JURONG WEST      1975.000000  1.339636  103.707339               0
# KALLANG/WHAMPOA  2300.000000  1.319116  103.866291               2
# MARINE PARADE    1950.000000  1.302689  103.907395               1
# PASIR RIS        2066.666667  1.375989  103.954360               4
# PUNGGOL          1825.000000  1.405255  103.902354               2
# QUEENSTOWN       2162.500000  1.294623  103.806045               2
# SEMBAWANG        1883.333333  1.448065  103.820760               3
# SENGKANG         1900.000000  1.390949  103.895175               4
# SERANGOON        2187.500000  1.349807  103.873771               1
# TAMPINES         2075.000000  1.354653  103.943571               0
# TOA PAYOH        2210.000000  1.335391  103.849741               3
# WOODLANDS        1762.500000  1.436897  103.786216               0
# YISHUN           1900.000000  1.428136  103.833694               0
#
#                  1st Most Common Venue  2nd Most Common Venue  \
# Town
# ANG MO KIO                 Food Courts  Fast Food Restaurants
# BEDOK                      Food Courts   Japanese Restaurants
# BISHAN                    Coffee Shops    Chinese Restaurants
# BUKIT BATOK                Food Courts    Chinese Restaurants
# BUKIT MERAH                      Cafés    Chinese Restaurants
# BUKIT PANJANG              Food Courts          Noodle Houses
# CENTRAL                    Food Courts    Seafood Restaurants
# CHOA CHU KANG    Fast Food Restaurants    Chinese Restaurants
# CLEMENTI                   Food Courts    Chinese Restaurants
# GEYLANG            Chinese Restaurants  Fast Food Restaurants
# HOUGANG                   Coffee Shops            Food Courts
# JURONG EAST        Chinese Restaurants  Fast Food Restaurants
# JURONG WEST      Fast Food Restaurants            Food Courts
# KALLANG/WHAMPOA    Chinese Restaurants            Food Courts
# MARINE PARADE             Coffee Shops                  Cafés
# PASIR RIS                        Cafés           Coffee Shops
# PUNGGOL                    Food Courts    Chinese Restaurants
# QUEENSTOWN         Chinese Restaurants            Food Courts
# SEMBAWANG                 Coffee Shops      Asian Restaurants
# SENGKANG                         Cafés               Bakeries
# SERANGOON        Fast Food Restaurants           Coffee Shops
# TAMPINES                   Food Courts           Coffee Shops
# TOA PAYOH                 Coffee Shops            Food Courts
# WOODLANDS                  Food Courts   Japanese Restaurants
# YISHUN                     Food Courts    Chinese Restaurants
#
#                  3rd Most Common Venue  4th Most Common Venue  \
# Town
# ANG MO KIO            Bubble Tea Shops           Pastry Shops
# BEDOK                    Noodle Houses           Coffee Shops
# BISHAN                     Food Courts   Japanese Restaurants
# BUKIT BATOK               Coffee Shops       Bubble Tea Shops
# BUKIT MERAH                   Bakeries            Food Courts
# BUKIT PANJANG      Chinese Restaurants           Coffee Shops
# CENTRAL                          Cafés           Coffee Shops
# CHOA CHU KANG        Asian Restaurants          Dessert Shops
# CLEMENTI         Fast Food Restaurants            Soup Places
# GEYLANG                    Food Courts          Noodle Houses
# HOUGANG                  Noodle Houses      Asian Restaurants
# JURONG EAST                Food Courts       Thai Restaurants
# JURONG WEST       Japanese Restaurants      Asian Restaurants
# KALLANG/WHAMPOA      Asian Restaurants  Fast Food Restaurants
# MARINE PARADE                 Bakeries                Bistros
# PASIR RIS                     Bakeries            Food Courts
# PUNGGOL                          Cafés  Fast Food Restaurants
# QUEENSTOWN                       Cafés          Noodle Houses
# SEMBAWANG                  Food Courts             BBQ Joints
# SENGKANG         Fast Food Restaurants            Food Courts
# SERANGOON                        Cafés   Japanese Restaurants
# TAMPINES         Fast Food Restaurants     Hotpot Restaurants
# TOA PAYOH          Chinese Restaurants                  Cafés
# WOODLANDS                 Snack Places   American Restaurants
# YISHUN                    Coffee Shops  Fast Food Restaurants
#
#                           5th Most Common Venue  6th Most Common Venue  \
# Town
# ANG MO KIO                          Restaurants           Coffee Shops
# BEDOK                     Fast Food Restaurants           Wings Joints
# BISHAN                    Fast Food Restaurants                  Cafés
# BUKIT BATOK               Fast Food Restaurants        Ice Cream Shops
# BUKIT MERAH                   Asian Restaurants           Coffee Shops
# BUKIT PANJANG              American Restaurants            Food Trucks
# CENTRAL                   Fast Food Restaurants       Bubble Tea Shops
# CHOA CHU KANG                       Food Courts                  Cafés
# CLEMENTI                          Dessert Shops           Coffee Shops
# GEYLANG          Vegetarian / Vegan Restaurants      Asian Restaurants
# HOUGANG                             Steakhouses  Fast Food Restaurants
# JURONG EAST                        Coffee Shops                  Cafés
# JURONG WEST                 Chinese Restaurants     Korean Restaurants
# KALLANG/WHAMPOA                    Coffee Shops             Cafeterias
# MARINE PARADE                       Food Courts    Seafood Restaurants
# PASIR RIS                   Chinese Restaurants  Fast Food Restaurants
# PUNGGOL                            Coffee Shops           Pizza Places
# QUEENSTOWN                        Dessert Shops     Indian Restaurants
# SEMBAWANG                 Fast Food Restaurants           Wings Joints
# SENGKANG                           Coffee Shops             Cafeterias
# SERANGOON                           Food Courts     Indian Restaurants
# TAMPINES                    Chinese Restaurants   Fried Chicken Joints
# TOA PAYOH                 Fast Food Restaurants            Steakhouses
# WOODLANDS                                 Cafés  Fast Food Restaurants
# YISHUN                       Hainan Restaurants          Noodle Houses
#
#                       7th Most Common Venue           8th Most Common Venue  \
# Town
# ANG MO KIO              Miscellaneous Shops     Modern European Restaurants
# BEDOK                              Bakeries                 Breakfast Spots
# BISHAN                     Bubble Tea Shops             Shaanxi Restaurants
# BUKIT BATOK               Asian Restaurants                  Grocery Stores
# BUKIT MERAH                 Ice Cream Shops              Korean Restaurants
# BUKIT PANJANG           Seafood Restaurants                          Plazas
# CENTRAL                             Lounges                    Pizza Places
# CHOA CHU KANG             Sushi Restaurants                    Coffee Shops
# CLEMENTI               American Restaurants              Indian Restaurants
# GEYLANG                       Dessert Shops                      BBQ Joints
# HOUGANG                     Sandwich Places              Indian Restaurants
# JURONG EAST                      Cafeterias              Hotpot Restaurants
# JURONG WEST                           Cafés                 Sandwich Places
# KALLANG/WHAMPOA         Seafood Restaurants                   Dessert Shops
# MARINE PARADE                 Noodle Houses             Chinese Restaurants
# PASIR RIS                      Snack Places                          Diners
# PUNGGOL               Cantonese Restaurants                     Restaurants
# QUEENSTOWN         Chinese Breakfast Places  Vegetarian / Vegan Restaurants
# SEMBAWANG                             Cafés              Hotpot Restaurants
# SENGKANG                Chinese Restaurants               Ramen Restaurants
# SERANGOON        Japanese Curry Restaurants              Korean Restaurants
# TAMPINES               Dumpling Restaurants          Portuguese Restaurants
# TOA PAYOH                   Sandwich Places               Asian Restaurants
# WOODLANDS                      Coffee Shops             Chinese Restaurants
# YISHUN                    Sushi Restaurants                    Pastry Shops
#
#                  9th Most Common Venue          10th Most Common Venue
# Town
# ANG MO KIO               Dessert Shops                      Pharmacies
# BEDOK                 Bubble Tea Shops                   Burger Joints
# BISHAN                  Burrito Places            Fried Chicken Joints
# BUKIT BATOK            Sandwich Places  Vegetarian / Vegan Restaurants
# BUKIT MERAH              Cupcake Shops              Hainan Restaurants
# BUKIT PANJANG               BBQ Joints                        Bakeries
# CENTRAL          Cantonese Restaurants               Ramen Restaurants
# CHOA CHU KANG              Restaurants                   Noodle Houses
# CLEMENTI           Italian Restaurants              French Restaurants
# GEYLANG          Taiwanese Restaurants                     Steakhouses
# HOUGANG            Italian Restaurants                     Food Stands
# JURONG EAST        Italian Restaurants            Japanese Restaurants
# JURONG WEST        Dim Sum Restaurants                   Noodle Houses
# KALLANG/WHAMPOA             Juice Bars                           Cafés
# MARINE PARADE       German Restaurants              Indian Restaurants
# PASIR RIS           Hotpot Restaurants               Greek Restaurants
# PUNGGOL                  Noodle Houses                 Sandwich Places
# QUEENSTOWN            Thai Restaurants                 Breakfast Spots
# SEMBAWANG         Japanese Restaurants                      Juice Bars
# SENGKANG                   Restaurants             Dim Sum Restaurants
# SERANGOON         Dumpling Restaurants                   Noodle Houses
# TAMPINES          Japanese Restaurants                     Restaurants
# TOA PAYOH          Italian Restaurants        Chinese Breakfast Places
# WOODLANDS           Indian Restaurants              Korean Restaurants
# YISHUN            Fried Chicken Joints                     Soup Places

# %%
fileName = "sg_top_clusters.csv"
linkName = "IBM Storage Link:" + fileName
create_download_link(sg_merged,linkName,fileName)
# Out:
# <a download="sg_top_clusters.csv" href="data:text/csv;base64,..." target="_blank">IBM Storage Link:sg_top_clusters.csv</a>

# %%
map_clusters = folium.Map(location=[latitude, longitude], tiles="Openstreetmap", zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(sg_merged['Latitude'], sg_merged['Longitude'], sg_merged.index.values,kmeans.labels_):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=1).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
